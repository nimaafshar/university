# %% [markdown]
# # Hands on

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from pandas_profiling import ProfileReport

# %%
train_data = pd.read_csv('airline-train.csv')

# %%
train_data.rename(columns={'Unnamed: 0':'key'},inplace=True)

# %%
train_data.set_index('key',inplace=True)

# %%
train_data
# Out:
#         _unit_id  _golden _unit_state  _trusted_judgments _last_judgment_at  \
# key
# 11429  681462729    False   finalized                   3      2/25/15 3:07
# 9717   681461003    False   finalized                   3      2/25/15 3:20
# 10153  681461443    False   finalized                   3      2/25/15 6:20
# 975    681449647    False   finalized                   3      2/25/15 2:14
# 1511   681450373    False   finalized                   3      2/25/15 6:57
# ...          ...      ...         ...                 ...               ...
# 5233   681455231    False   finalized                   3      2/25/15 7:08
# 7222   681457720    False   finalized                   3      2/25/15 9:45
# 10227  681461517    False   finalized                   3      2/25/15 2:07
# 5549   681455548    False   finalized                   3      2/25/15 9:04
# 10968  681462263    False   finalized                   3      2/25/15 7:22
#
#       airline_sentiment  airline_sentiment:confidence          negativereason  \
# key
# 11429          positive                        1.0000                     NaN
# 9717           negative                        1.0000              Can't Tell
# 10153          negative                        1.0000              Can't Tell
# 975            negative                        1.0000              Can't Tell
# 1511           negative                        1.0000              Can't Tell
# ...                 ...                           ...                     ...
# 5233           negative                        0.6334        Cancelled Flight
# 7222           negative                        1.0000              Bad Flight
# 10227          negative                        1.0000             Late Flight
# 5549           negative                        1.0000  Customer Service Issue
# 10968          negative                        1.0000              Can't Tell
#
#        negativereason:confidence     airline airline_sentiment_gold  \
# key
# 11429                        NaN  US Airways                    NaN
# 9717                      0.3464  US Airways                    NaN
# 10153                     1.0000  US Airways                    NaN
# 975                       1.0000      United                    NaN
# 1511                      0.6848      United                    NaN
# ...                          ...         ...                    ...
# 5233                      0.6334   Southwest                    NaN
# 7222                      0.6658       Delta                    NaN
# 10227                     1.0000  US Airways                    NaN
# 5549                      1.0000   Southwest                    NaN
# 10968                     0.6744  US Airways                    NaN
#
#                 name negativereason_gold  retweet_count  \
# key
# 11429   CaraModisett                 NaN              0
# 9717    LarrySandeen                 NaN              0
# 10153        burseka                 NaN              0
# 975    artistanxiety                 NaN              0
# 1511       axelrodaj                 NaN              0
# ...              ...                 ...            ...
# 5233     hoffmanrich                 NaN              0
# 7222          SL_024                 NaN              0
# 10227     CakeNDeath                 NaN              0
# 5549       rawbeeeen                 NaN              0
# 10968  RVangutenberg                 NaN              0
#
#                                                     text  \
# key
# 11429  @USAirways she also appreciated having her ver...
# 9717   @USAirways Just discovered that they billed us...
# 10153                             @USAirways u guys suck
# 975            @united I will but right now I'm to angry
# 1511   @united not sure why the people in row 7 that ...
# ...                                                  ...
# 5233   @SouthwestAir flight 4040 atl to lga Cancelled...
# 7222   @JetBlue keeps getting better. No water on the...
# 10227  @USAirways @AmericanAir working for me. Tight ...
# 5549   @SouthwestAir are you guys alive? i've been on...
# 10968  @USAirways NEVER AGAIN! Worse experience in my...
#
#                         tweet_coord  tweet_created      tweet_id  \
# key
# 11429                           NaN  2/18/15 10:55  5.681220e+17
# 9717                     [0.0, 0.0]  2/22/15 19:24  5.696990e+17
# 10153                           NaN   2/22/15 7:28  5.695190e+17
# 975                             NaN  2/23/15 14:09  5.699820e+17
# 1511   [33.94077727, -118.39921036]  2/22/15 18:50  5.696910e+17
# ...                             ...            ...           ...
# 5233                            NaN  2/21/15 13:12  5.692430e+17
# 7222                            NaN   2/23/15 7:00  5.698740e+17
# 10227                           NaN   2/22/15 4:55  5.694810e+17
# 5549                            NaN  2/20/15 14:44  5.689040e+17
# 10968                           NaN   2/20/15 2:54  5.687250e+17
#
#                       tweet_location               user_timezone
# key
# 11429             Memphis, Tennessee  Central Time (US & Canada)
# 9717   Southeastern Pennsylvania USA                         NaN
# 10153                            NaN                         NaN
# 975            Punk is the preacher.                     Arizona
# 1511                   San Francisco  Pacific Time (US & Canada)
# ...                              ...                         ...
# 5233                 Long Island, NY  Eastern Time (US & Canada)
# 7222                             NaN  Eastern Time (US & Canada)
# 10227                Old City Philly                         NaN
# 5549                             310  Pacific Time (US & Canada)
# 10968                    Puerto Rico                         NaN
#
# [8784 rows x 20 columns]

# %%
train_data.describe()
# Out:
#            _unit_id  _trusted_judgments  airline_sentiment:confidence  \
# count  8.784000e+03         8784.000000                   8784.000000
# mean   6.814968e+08            3.668944                      0.901426
# std    8.589781e+04           12.323107                      0.161894
# min    6.814482e+08            2.000000                      0.336600
# 25%    6.814537e+08            3.000000                      0.693900
# 50%    6.814579e+08            3.000000                      1.000000
# 75%    6.814623e+08            3.000000                      1.000000
# max    6.816798e+08          248.000000                      1.000000
#
#        negativereason:confidence  retweet_count      tweet_id
# count                6308.000000    8784.000000  8.784000e+03
# mean                    0.644660       0.077527  5.692274e+17
# std                     0.327245       0.705229  7.777708e+14
# min                     0.000000       0.000000  5.675880e+17
# 25%                     0.362675       0.000000  5.685738e+17
# 50%                     0.671300       0.000000  5.694990e+17
# 75%                     1.000000       0.000000  5.698940e+17
# max                     1.000000      44.000000  5.703090e+17

# %%
profile = ProfileReport(train_data,title="Pandas Profiling Report")

# %%
profile.to_widgets()
# Out:
# HBox(children=(HTML(value='Summarize dataset'), FloatProgress(value=0.0, max=35.0), HTML(value='')))
